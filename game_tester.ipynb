# %% [markdown]
# # A tester for the Game instance

# %%
from brumaire.agent import RandomAgent
from brumaire.session import Game
from brumaire.rendering.board import BoardComponent

# %% [markdown]
# ## Hyperparameters

# %%
BOARD_NUM = 10
AGENTS = [RandomAgent(), RandomAgent(), RandomAgent(), RandomAgent(), RandomAgent()]

# %% [markdown]
# ## Start a game
#
# Decide napoleons.

# %%
game = Game(BOARD_NUM, AGENTS, log_enabled=True)
game.decide_napoleon()

# %%
game.board.decl[0]
# Out:
# array([ 2, 13])

# %%
game.board.roles[0]
# Out:
# array([2, 3, 3, 1, 3])

# %%
game.board.get_napoleon()[0]
# Out:
# 3

# %% [markdown]
# Discard additional cards.

# %%
game.discard_additional_cards()

# %% [markdown]
# Do tricks

# %%
for idx in range(10):
    game.trick(idx)

# %%
game.check_result()

# %% [markdown]
# ## Results

# %%
game.board.taken[0]
# Out:
# array([ 2,  0, 12,  2,  2])

# %%
game.logs[0]
# Out:
# ['player0 is a first player.',
#  'player0 declared DIAMOND 13.',
#  'player1 declared SPADE 12.',
#  'player2 declared DIAMOND 12.',
#  'player3 declared HEART 13.',
#  'player4 declared HEART 13.',
#  'There is a valid goal.',
#  'player3 is a napoleon for HEART 13.',
#  'The adjutant card is CLUB 2.',
#  'player3 discards CLUB 5.',
#  'player3 discards CLUB Q.',
#  'player3 discards DIAMOND 7.',
#  'player3 discards SPADE 10.',
#  '--- TRICK: 0 ---',
#  'player3 puts SPADE 5.',
#  'player4 puts SPADE 2.',
#  'player0 puts SPADE 9.',
#  'player1 puts SPADE Q.',
#  'player2 puts SPADE K.',
#  'player4 wins the trick.',
#  '--- TRICK: 1 ---',
#  'player4 puts SPADE 3.',
#  'player0 puts SPADE 6.',
#  'player1 puts DIAMOND 2.',
#  'player2 puts SPADE A.',
#  'player3 puts SPADE 8.',
#  'player2 wins the trick.',
#  '--- TRICK: 2 ---',
#  'player2 puts HEART J.',
#  'player3 puts HEART 3.',
#  'player4 puts HEART A.',
#  'player0 puts JOKER.',
#  'player1 puts HEART 8.',
#  'player2 wins the trick.',
#  '--- TRICK: 3 ---',
#  'player2 puts HEART K.',
#  'player3 puts JOKER.',
#  'player4 puts CLUB A.',
#  'player0 puts HEART Q.',
#  'player1 puts DIAMOND 5.',
#  'player2 wins the trick.',
#  '--- TRICK: 4 ---',
#  'player2 puts HEART 7.',
#  'player3 puts HEART 9.',
#  'player4 puts DIAMOND Q.',
#  'player0 puts HEART 6.',
#  'player1 puts DIAMOND 10.',
#  'player3 wins the trick.',
#  '--- TRICK: 5 ---',
#  'player3 puts CLUB 8.',
#  'player4 puts CLUB 6.',
#  'player0 puts CLUB 2.',
#  'player1 puts CLUB 3.',
#  'player2 puts SPADE 4.',
#  'player3 wins the trick.',
#  '--- TRICK: 6 ---',
#  'player3 puts CLUB 7.',
#  'player4 puts CLUB 9.',
#  'player0 puts SPADE 7.',
#  'player1 puts CLUB 10.',
#  'player2 puts HEART 2.',
#  'player2 wins the trick.',
#  '--- TRICK: 7 ---',
#  'player2 puts DIAMOND J.',
#  'player3 puts HEART 5.',
#  'player4 puts DIAMOND A.',
#  'player0 puts DIAMOND 9.',
#  'player1 puts DIAMOND 3.',
#  'player2 wins the trick.',
#  '--- TRICK: 8 ---',
#  'player2 puts HEART 10.',
#  'player3 puts CLUB J.',
#  'player4 puts SPADE J.',
#  'player0 puts HEART 4.',
#  'player1 puts DIAMOND 6.',
#  'player2 wins the trick.',
#  '--- TRICK: 9 ---',
#  'player2 puts DIAMOND 8.',
#  'player3 puts CLUB K.',
#  'player4 puts CLUB 4.',
#  'player0 puts DIAMOND K.',
#  'player1 puts DIAMOND 4.',
#  'player0 wins the trick.',
#  'player1, player2, player4 win(s).']

# %%
game.recorder.rewards[:, 0]
# Out:
# array([[-0.04, -0.02, -0.04, -0.06,  0.04,  0.  , -0.02, -0.04, -0.06,
#          0.04],
#        [ 0.04,  0.02,  0.04,  0.06, -0.04,  0.  ,  0.02,  0.04,  0.06,
#          0.96],
#        [ 0.04,  0.02,  0.04,  0.06, -0.04,  0.  ,  0.02,  0.04,  0.06,
#          0.96],
#        [-0.04, -0.02, -0.04, -0.06,  0.04,  0.  , -0.02, -0.04, -0.06,
#          0.04],
#        [ 0.04,  0.02,  0.04,  0.06, -0.04,  0.  ,  0.02,  0.04,  0.06,
#          0.96]])

# %%
game.recorder.win_rate(0)
# Out:
# 0.6

# %%
BoardComponent(0, game.board).render()
# Out:
# <PIL.Image.Image image mode=RGB size=830x470>
